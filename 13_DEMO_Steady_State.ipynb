# %%
using Fussy
Main.IJulia.set_current_module(Fussy)

return

# %%
reac = Reactor(18.067, deck=:demo_steady)

# %%
foo(x) = SymEngine.subs(
    x,
    SymEngine.symbols("n_bar") => 0.8746,
    SymEngine.symbols("I_P") => 21.627,
    SymEngine.symbols("R_0") => 7.500,
    SymEngine.symbols("B_0") => 5.627,
    SymEngine.symbols("sigma_v") => calc_sigma_v(reac)
) |> SymEngine.N

# %%
function bar(a,b,c) 
    cur_expected = c
    cur_actual = foo(b)
    cur_is_equal = isapprox(cur_expected, cur_actual, rtol=0.1)
    println(a, " = ", cur_expected, cur_is_equal ? " == " : "  !==  ", cur_actual)
end

# %% [markdown]
# ### This is bad!!!
#
# ##### τ_E has ~35% err
#
# // from power and/or kappa term

# %%
bar(
    "tau_E",
    tau_E(reac),
    4.027
)

# %%
bar(
    "P_LH",
    P_LH(reac),
    1.119E+02
)

# %%
bar(
    "R_P",
    R_P(reac),
    4.741E-09
)

# %%
bar(
    "P_F",
    P_F(reac),
    3.255E+03
)

# %%
bar(
    "P_alpha",
    P_alpha(reac),
    6.501E+02
)

# %%
bar(
    "P_alpha_core",
    P_alpha(reac),
    617.61
)

# %%
bar(
    "P_n",
    P_n(reac),
    2.602E+03
)

# %%
bar(
    "L_P",
    L_P(reac),
    1.016E-05
)

# %%
bar(
    "P_ohmic",
    P_ohmic(reac),
    2.217E-10
)

# %%
bar(
    "P_BR",
    P_BR(reac),
    2.100E+02
)

# %%
bar(
    "P_core",
    P_BR(reac),
    3.184E+02
)

# %%
bar(
    "volume",
    volume(reac),
    2.217E+03
)

# %%
bar(
    "surface_area",
    surface_area(reac),
    1.253E+03
)

# %%
bar(
    "perimeter",
    perimeter(reac),
    27.640
)

# %%
bar(
    "cross_sectional_area",
    cross_sectional_area(reac),
    48.341
)

# %%
bar(
    "P_H",
    P_H(reac),
    81.06 + 52.01
)

# %%
bar(
    "P_kappa",
    P_kappa(reac),
    round(236.86 + 198.43, 3)
)

# %%
bar(
    "P_out",
    P_kappa(reac) + P_BR(reac),
    753.65
)

# %%
bar(
    "P_in",
    P_alpha(reac) + P_H(reac),
    753.65
)

# %%
bar(
    "h_CS",
    h_CS(reac),
    12.46
)

# %%
bar(
    "R_CS",
    R_CS(reac),
    1.30
)

# %%
bar(
    "d",
    d(reac),
    0.50
)

# %%
bar(
    "c",
    c(reac),
    1.247
)

# %%
bar(
    "P_W",
    P_W(reac),
    1.911E+00
)

# %%
bar(
    "P_E (gross)",
    P_E(reac),
    1.660E+03
)

# %%
bar(
    "P_E (net)",
    P_E(reac) - P_H(reac) - P_alpha(reac),
    9.531E+02
)

# %%
bar(
    "B_P",
    B_P(reac),
    0.983
)

# %%
bar(
    "beta_P (total)",
    beta_P(reac),
    1.709
)

# %%
bar(
    "beta_P (thermal)",
    beta_P(reac),
    1.370
)

# %%
bar(
    "B_V",
    B_V(reac),
    abs(-1.065)
)

# %%
bar(
    "n_hat",
    n_hat(reac),
    0.9928
)

# %%
bar(
    "phi_FT",
    phi_FT(reac),
    1.025E-05
)

# %%
bar(
    "f_BS",
    f_BS(reac),
    0.611
)

# %%
bar(
    "beta_N",
    beta_N(reac),
    0.038
)

# %%
bar(
    "q_95",
    q_95(reac),
    4.405
)

# %%
bar(
    "phi_RU",
    phi_RU(reac),
    3.851E+02
)

# %%
bar(
    "phi_ind",
    phi_ind(reac),
    2.197E+02
)

# %%
bar(
    "phi_res",
    phi_res(reac),
    8.153E+01
)

# %%
bar(
    "V_loop",
    V_loop(reac),
    1.025E-11
)

# %%
bar(
    "phi_source",
    phi_CS(reac) + phi_PF(reac),
    301.18
)

# %%
bar(
    "phi_sink",
    phi_FT(reac) + phi_RU(reac),
      3.012E+02
)

# %%
bar(
    "phi_CS",
    phi_CS(reac),
    90.93
)

# %%
bar(
    "phi_PF",
    phi_PF(reac),
    210.25
)

# %%
struct

# %%
using Interpolations


x = [8.5, 9.0, 9.5, 10.0, 10.5, 11.0, 11.5, 12.0, 12.5, 13.0, 13.5, 13.5, 14.0, 14.0, 14.5, 15.0, 15.0, 15.5, 15.5, 16.0, 16.0, 16.5, 16.5, 17.0, 17.5, 17.5, 18.0, 18.5, 19.0, 19.5, 20.0, 20.5, 21.0, 21.0, 21.5, 21.5, 22.0, 22.0, 22.5, 22.5, 23.0, 23.0, 23.5, 23.5, 24.0, 24.0, 24.5, 24.5, 25.0, 25.0, 25.5, 25.5, 26.0, 26.0, 26.5, 26.5, 27.0, 27.0, 27.5, 27.5, 28.0, 28.0, 28.5, 28.5, 29.0, 29.0, 29.5, 29.5]
y = [70.63, 62.4039, 56.9534, 53.1338, 50.3512, 48.2673, 46.6756, 45.443, 44.4798, 43.7236, 8.95258, 43.1294, 9.48112, 42.6641, 42.3027, 10.5921, 42.0261, 11.1748, 41.8192, 11.7758, 41.67, 12.395, 41.5691, 41.5085, 13.6877, 41.4817, 41.4833, 41.5088, 41.554, 41.6156, 41.6906, 41.776, 18.8414, 41.8696, 19.6467, 41.9688, 20.4587, 42.0715, 21.2861, 42.1755, 22.1291, 42.2786, 22.9869, 42.3786, 23.8584, 42.4729, 24.7579, 42.559, 25.7081, 42.6339, 26.6841, 42.694, 27.6895, 42.7348, 28.7292, 42.7508, 29.8098, 42.7343, 30.9415, 42.6747, 32.1402, 42.5551, 33.4337, 42.3471, 34.8798, 41.9925, 36.6451, 41.324]
t = 1:length(x)
A = hcat(x,y)

itp = scale(interpolate(A, (BSpline(Cubic(Natural())), NoInterp()), OnGrid()), t, 1:2)

psa = Spline2D((A'); s=0.0)

itp = evalgrid(psa, x, y)

tfine = 1:0.2:length(x)

println(itp)
# xs, ys = [itp[t,1] for t in tfine], [itp[t,2] for t in tfine]

# %%
xs, ys = [itp[t,1] for t in tfine], [itp[t,2] for t in tfine]

scatter(x, y, label="knots")
plot!(xs, ys, label="spline")

# %%
Pkg.add("NearestNeighbors")
using NearestNeighbors

# %%
cur_tree = KDTree(A)

chains = []

aa,bb = knn(cur_tree, A, 3, true)

cc = []
dd = []

for (cur_a, cur_b) in zip(aa, bb)
    main_point, glue_point = cur_a[1], cur_a[2]
    push!(cc, cur_b[3]/cur_b[2])
    push!(dd, cur_b[2])
end

for cur_index in 1:length(cc)
    findmax(cc)
end

# %%
A

# %%
x = [5.5, 6.0, 6.5, 7.0, 7.5, 8.0, 8.5, 9.0, 9.5, 10.0, 10.5, 11.0, 11.5, 11.5, 11.5, 12.0, 12.0, 12.0, 12.5, 12.5, 12.5, 13.0, 13.0, 13.0, 13.5, 13.5, 13.5, 14.0, 14.0, 14.0, 14.5, 14.5, 14.5, 15.0, 15.0, 15.0, 15.5, 15.5, 15.5, 16.0, 16.0, 16.0, 16.5, 16.5, 16.5, 17.0, 17.0, 17.0, 17.5, 17.5, 17.5, 18.0, 18.0, 18.0, 18.5, 18.5, 18.5, 19.0, 19.0, 19.0, 19.5, 19.5, 19.5, 20.0, 20.0, 20.0, 20.5, 20.5, 20.5, 21.0, 21.0, 21.0, 21.5, 21.5, 21.5, 22.0, 22.0, 22.0, 22.5, 22.5, 22.5, 23.0, 23.0, 23.0, 23.5, 23.5, 23.5, 24.0, 24.0, 24.0, 24.5, 24.5, 24.5, 25.0, 25.0, 25.0, 25.5, 25.5, 25.5, 26.0, 26.0, 26.0, 26.5, 26.5, 26.5, 27.0, 27.0, 27.0, 27.5, 27.5, 27.5, 28.0, 28.0, 28.0, 28.5, 28.5, 28.5, 29.0, 29.0, 29.0, 29.5, 29.5, 29.5, 30.0, 30.0, 30.0, 30.5, 30.5, 30.5, 31.0, 31.0, 31.0, 31.5, 31.5, 31.5, 32.0, 32.0, 32.0, 32.5, 32.5, 32.5, 33.0, 33.0, 33.0, 33.5, 33.5, 33.5, 34.0, 34.0, 34.0, 34.5, 34.5, 34.5, 35.0, 35.0, 35.0, 35.5, 35.5, 35.5, 36.0, 36.0, 36.0, 36.5, 36.5, 36.5, 37.0, 37.0, 37.0, 37.5, 37.5, 37.5, 38.0, 38.0, 38.0, 38.5, 38.5, 38.5, 39.0, 39.0, 39.0, 39.5, 39.5, 39.5, 40.0, 40.0, 40.0]
y = [51.2529, 36.3723, 29.7581, 26.1178, 23.8735, 22.3932, 21.3759, 20.66, 20.1515, 19.7918, 19.5426, 19.3779, 12.509, 12.5781, 19.2794, 12.5924, 12.7356, 19.2339, 12.7051, 12.9129, 19.2317, 12.8384, 13.1122, 19.2654, 12.9883, 13.3324, 19.3294, 13.1521, 13.5723, 19.4194, 13.328, 13.8309, 19.5318, 13.5143, 14.1073, 19.6641, 13.7099, 14.4007, 19.8139, 13.9138, 14.7102, 19.9797, 14.1252, 15.0351, 20.1599, 14.3434, 15.3745, 20.3534, 14.5679, 15.7276, 20.5591, 14.7981, 16.0933, 20.